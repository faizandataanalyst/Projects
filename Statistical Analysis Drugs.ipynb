# %% [markdown]
# # Statistical Analysis of Drugs Data

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %%
df = pd.read_csv('C:\\Users\\osman\\Desktop\\Jupyter Codes\\Jupyter Notebook code\\Wrangled Data of Drug.csv')
df
# Out:
#      Unnamed: 0       Age  Sex  BP  Cholesterol   Na_to_K   Drug
# 0             0  4.523562    0   2            1  4.664198  drugY
# 1             1  5.554589    1   0            1  3.710724  drugC
# 2             2  5.554589    1   0            1  3.338282  drugC
# 3             3  4.807355    0   1            1  2.963104  drugX
# 4             4  5.930737    0   0            1  4.173367  drugY
# ..          ...       ...  ...  ..          ...       ...    ...
# 195         195  5.807355    0   0            1  3.531943  drugC
# 196         196  4.000000    1   0            1  3.585684  drugC
# 197         197  5.700440    1   1            1  3.306554  drugX
# 198         198  4.523562    1   1            0  3.809414  drugX
# 199         199  5.321928    0   0            0  3.504493  drugX
#
# [200 rows x 7 columns]

# %% [markdown]
# ## Descriptive Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   200 non-null    int64
#  1   Age          200 non-null    float64
#  2   Sex          200 non-null    int64
#  3   BP           200 non-null    int64
#  4   Cholesterol  200 non-null    int64
#  5   Na_to_K      200 non-null    float64
#  6   Drug         200 non-null    object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 11.1+ KB

# %%
print(df['Age'].nunique())
print()
print(df['Sex'].nunique())
print()
print(df['BP'].nunique())
print()
print(df['Cholesterol'].nunique())
print()
print(df['Na_to_K'].nunique())
print()
print(df['Drug'].nunique())
# Out:
# 57
#
# 2
#
# 3
#
# 2
#
# 198
#
# 5

# %%
print(df['Age'].unique())
print()
print(df['Sex'].unique())
print()
print(df['BP'].unique())
print()
print(df['Cholesterol'].unique())
print()
print(df['Na_to_K'].unique())
print()
print(df['Drug'].unique())
# Out:
# [4.52356196 5.55458885 4.80735492 5.93073734 4.45943162 5.61470984
#  5.357552   5.9068906  5.42626475 5.08746284 6.20945337 5.64385619
#  4.         6.10852446 5.         5.83289001 5.97727992 5.5849625
#  5.04439412 4.95419631 5.28540222 5.4918531  4.169925   6.02236781
#  5.72792045 5.52356196 3.9068906  6.18982456 5.857981   6.04439412
#  5.20945337 6.08746284 6.06608919 5.95419631 4.5849625  4.70043972
#  5.32192809 5.24792751 4.857981   4.08746284 5.7548875  6.12928302
#  5.169925   4.24792751 6.         5.88264305 5.67242534 5.39231742
#  5.80735492 4.32192809 6.169925   5.12928302 5.70043972 5.78135971
#  4.9068906  4.39231742 4.64385619]
#
# [0 1]
#
# [2 0 1]
#
# [1 0]
#
# [4.66419837 3.71072379 3.33828178 2.96310415 4.17336733 3.10551047
#  4.02458564 3.46427618 3.92324428 4.27560308 3.55667465 4.26295926
#  3.94260834 4.38832732 3.66709735 3.95568478 3.51790555 3.80446664
#  2.86750115 4.6989963  4.25761413 4.69582682 4.93395026 3.91034892
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex          BP  Cholesterol     Na_to_K
# count  200.000000  200.000000  200.000000  200.000000   200.000000  200.000000
# mean    99.500000    5.353742    0.520000    1.065000     0.515000    3.875862
# std     57.879185    0.606522    0.500854    0.839224     0.501029    0.609068
# min      0.000000    3.906891    0.000000    0.000000     0.000000    2.648235
# 25%     49.750000    4.954196    0.000000    0.000000     0.000000    3.384810
# 50%     99.500000    5.491853    1.000000    1.000000     1.000000    3.800796
# 75%    149.250000    5.857981    1.000000    2.000000     1.000000    4.276496
# max    199.000000    6.209453    1.000000    2.000000     1.000000    5.257275

# %% [markdown]
# ## Deep Dig using Plots

# %% [markdown]
# #### df['BP'] = df['BP'].map({'LOW': 0, 'NORMAL': 1, 'HIGH': 2})
# #### df['Sex'] = df['Sex'].map({'F': 0, 'M': 1})
# #### df['Cholesterol'] = df['Cholesterol'].map({'NORMAL': 0, 'HIGH': 1})
# #### df['Drug'] = df['Drug'].map({'drugY' : 0, 'drugC' : 1 , 'drugX ' : 2, 'drugA' : 3, 'drugB' : 4})

# %%
sns.boxplot(df,x = "Sex", y="Age")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(df,x = "Sex", y="Na_to_K")
# Out:
# <Axes: xlabel='Sex', ylabel='Na_to_K'>

# %%
sns.scatterplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(df['Na_to_K'])
# Out:
# <Axes: ylabel='Na_to_K'>

# %%
sns.barplot(x=df['BP'], y=df['Sex'])
# Out:
# <Axes: xlabel='BP', ylabel='Sex'>

# %%
category_counts = df['Drug'].value_counts()

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart for Drug Categories')
plt.show()

# %%
category_counts = df['Cholesterol'].value_counts()

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart for Cholesterol Categories')
plt.show()

# %%
category_counts = df['BP'].value_counts()

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart for BP Categories')
plt.show()

# %%
sns.violinplot(df['Na_to_K'])
plt.title('Violin Plot for Na_to_K')
plt.show()

# %%
sns.violinplot(df['Age'])
plt.title('Violin Plot for Age')
plt.show()

# %% [markdown]
# ## Normaity Check

# %% [markdown]
# ### Age Column

# %% [markdown]
# \\ Null Hypothesis: Data is Normal.

# %% [markdown]
# \\ Alternate Hypothesis: Data is not Normal.

# %%
sns.histplot(df['Age'], kde=1)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df["Age"], kde = True)
plt.axvline(df["Age"].mean(), color="Red")
plt.axvline(df["Age"].median(), color="Green")
plt.axvline(df["Age"].mode()[0], color="Blue")

# Print 
print("Mean : ", df["Age"].mean())
print("Median : ", df["Age"].median())
print("Mode : ", df["Age"].mode()[0])
# Out:
# Mean :  5.353741821315088
# Median :  5.491853096329675
# Mode :  5.554588851677638

# %%
stats.shapiro(df['Age'])
# Out:
# ShapiroResult(statistic=0.9437012672424316, pvalue=4.878829145127384e-07)

# %% [markdown]
# ##### Based on the results of the normality test conducted at a significance level of [pvalue=4.878829145127384e-07], we do not have sufficient evidence to accept the null hypothesis. Therefore, we do not conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ### NA_to_K Column

# %% [markdown]
# \\ Null Hypothesis : Data is Normal.

# %% [markdown]
# \\ Alternate Hypothesis : Data is not Normal.

# %%
sns.histplot(df['Na_to_K'], kde=1)
# Out:
# <Axes: xlabel='Na_to_K', ylabel='Count'>

# %%
sns.histplot(df["Na_to_K"], kde = True)
plt.axvline(df["Na_to_K"].mean(), color="Red")
plt.axvline(df["Na_to_K"].median(), color="Green")
plt.axvline(df["Na_to_K"].mode()[0], color="Blue")

# Print 
print("Mean : ", df["Na_to_K"].mean())
print("Median : ", df["Na_to_K"].median())
print("Mode : ", df["Na_to_K"].mode()[0])
# Out:
# Mean :  3.875861707101687
# Median :  3.800796376098481
# Mode :  3.5856836679648105

# %%
stats.shapiro(df['Na_to_K'])
# Out:
# ShapiroResult(statistic=0.9753081202507019, pvalue=0.0013494194718077779)

# %% [markdown]
# ##### Based on the results of the normality test conducted at a significance level of [pvalue=0.001349419471807777], we do not have sufficient evidence to accept the null hypothesis. Therefore, we do not conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ## Levene Test

# %% [markdown]
# \\ Null Hypothesis : Data is Normal.

# %% [markdown]
# \\ Alternate Hypothesis : Data is not Normal.

# %%
group1 = (df['Age'])
group2 = (df["Na_to_K"])

# Perform Levene Test
w_stat, p_val = stats.levene(group1, group2)

print("w_statistic:", w_stat)
print("p-value:", p_val)

if p_val < 0.05:  # Assuming alpha level of 0.05
    print(f"Variance are equal : Fail to Reject the null hypothesis")
else:
    print(f"Variance are not equal : Reject the null hypothesis")
# Out:
# w_statistic: 0.01729232639401157
# p-value: 0.8954460039049175
# Variance are not equal : Reject the null hypothesis

# %% [markdown]
# ##### Based on the results of the homoginity test conducted at a significance level of [p-value: 0.8954460039049175, w_statistic: 0.01729232639401157], (variance are not equal) we do not have sufficient evidence to accept the null hypothesis. Therefore, we do not conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ## Non-Parametric Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   200 non-null    int64
#  1   Age          200 non-null    float64
#  2   Sex          200 non-null    int64
#  3   BP           200 non-null    int64
#  4   Cholesterol  200 non-null    int64
#  5   Na_to_K      200 non-null    float64
#  6   Drug         200 non-null    object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# ### Chi-Squared Test

# %% [markdown]
# #### BP Column

# %%
contigency_table_1 = pd.crosstab(df["Sex"], df["BP"])
contigency_table_1
# Out:
# BP    0   1   2
# Sex
# 0    28  30  38
# 1    36  29  39

# %%
chi2, p, dof, expected = stats.chi2_contingency(contigency_table_1)

print()
print("Chi_Square Statistic:", chi2)
print("p-value:", p)
print("Degrees of Freedom:", dof)
print("Expected:", expected)
# Out:
# Chi_Square Statistic: 0.7110738837433747
# p-value: 0.7007970548859668
# Degrees of Freedom: 2
# Expected: [[30.72 28.32 36.96]
#  [33.28 30.68 40.04]]

# %% [markdown]
# #### Cholesterol Column

# %%
contigency_table_2= pd.crosstab(df["Sex"], df["Cholesterol"])
contigency_table_2
# Out:
# Cholesterol   0   1
# Sex
# 0            47  49
# 1            50  54

# %%
chi2, p, dof, expected = stats.chi2_contingency(contigency_table_2)

print()
print("Chi_Square Statistic:", chi2)
print("p-value:", p)
print("Degrees of Freedom:", dof)
print("Expected:", expected)
# Out:
# Chi_Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 1
# Expected: [[46.56 49.44]
#  [50.44 53.56]]

# %% [markdown]
# #### Drug Column

# %%
contigency_table_3 = pd.crosstab(df["Sex"], df["Drug"])
contigency_table_3
# Out:
# Drug  drugA  drugB  drugC  drugX  drugY
# Sex
# 0         9      6      7     27     47
# 1        14     10      9     27     44

# %%
chi2, p, dof, expected = stats.chi2_contingency(contigency_table_3)

print()
print("Chi_Square Statistic:", chi2)
print("p-value:", p)
print("Degrees of Freedom:", dof)
print("Expected:", expected)
# Out:
# Chi_Square Statistic: 2.119248418109203
# p-value: 0.7138369773987128
# Degrees of Freedom: 4
# Expected: [[11.04  7.68  7.68 25.92 43.68]
#  [11.96  8.32  8.32 28.08 47.32]]

# %% [markdown]
# ### Man-Whitney Test (for Independent sample t-test )

# %%
from scipy.stats import mannwhitneyu

group1 = df['Age']
group2 = df['Na_to_K']

# Perform Mann-Whitney U test
statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

print(f'Mann-Whitney U statistic: {statistic}, p-value: {p_value}')
# Out:
# Mann-Whitney U statistic: 37876.0, p-value: 6.281250894480361e-54

# %% [markdown]
# ### Correlation

# %%
def pearson(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    x_std = np.std(x)
    y_std = np.std(y)
    n = len(x)
    return sum((x-x_mean)*(y-y_mean))/(n*x_std*y_std)

def spearman(x,y):
    x_rank = pd.Series(x).rank()
    y_rank = pd.Series(y).rank()
    return pearson(x_rank,y_rank)

# Example Dataset
x=(df["Age"])
y=(df["Na_to_K"])

print(f"Spearman Correlation Coefficient: {spearman(x,y)}")
# Differentiate all values
if spearman(x,y) < 0.6 > 0:
    print("Positive Relation")
elif spearman(x,y) > 0.6:
    print("Highly Positive Relation")
elif spearman(x,y) > -0.6 < 0:
    print("Negative Correlation")
elif  spearman(x,y) < -0.6:
    print("Highly Negative Correlation")
else:
    print("No Relation")
# Out:
# Spearman Correlation Coefficient: -0.047273882688479915
# Positive Relation

# %%
data =pd.DataFrame({'Age': x, 'Na_to_K': y})
heatmap_data = data.corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap between Age and Na_to_K')
plt.show()
