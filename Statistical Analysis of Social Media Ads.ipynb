# %% [markdown]
# # Statistical Analysis of Social Media Ads Dataset

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %%
df = pd.read_csv('C:\\Users\\osman\\Desktop\\Jupyter Codes\\Jupyter Notebook code\\Pre-processing\\Wrangled Data of Social Media Ads.csv')
df
# Out:
#      Unnamed: 0  Gender       Age  EstimatedSalary  Purchased
# 0             0       0  2.944439        11.156065          0
# 1             1       0  3.610918         9.903488          0
# 2             2       1  3.258097        10.668955          0
# 3             3       1  3.610918        10.950807          0
# 4             4       0  2.944439        11.238489          0
# ..          ...     ...       ...              ...        ...
# 395         395       1  3.828641        10.621327          1
# 396         396       0  3.931826        10.043249          1
# 397         397       1  3.912023         9.903488          1
# 398         398       0  3.583519        10.404263          0
# 399         399       1  3.891820        10.491274          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ## Descriptive Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       400 non-null    int64
#  1   Gender           400 non-null    int64
#  2   Age              400 non-null    float64
#  3   EstimatedSalary  400 non-null    float64
#  4   Purchased        400 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 15.8 KB

# %%
print(df['Age'].nunique())
print()
print(df['Gender'].nunique())
print()
print(df['EstimatedSalary'].nunique())
print()
print(df['Purchased'].nunique())
# Out:
# 43
#
# 2
#
# 118
#
# 2

# %%
print(df['Age'].unique())
print()
print(df['Gender'].unique())
print()
print(df['EstimatedSalary'].unique())
print()
print(df['Purchased'].unique())
# Out:
# [2.94443898 3.61091791 3.25809654 3.29583687 3.21887582 3.55534806
#  2.99573227 2.89037176 3.36729583 3.8501476  3.80666249 3.8286414
#  3.87120101 3.8918203  3.4339872  3.04452244 3.33220451 3.49650756
#  3.40119738 3.13549422 3.17805383 3.09104245 3.4657359  4.07753744
#  3.52636052 3.66356165 3.63758616 3.73766962 3.68887945 3.58351894
#  3.71357207 4.06044301 4.00733319 3.95124372 4.09434456 4.02535169
#  3.97029191 3.91202301 3.93182563 4.04305127 3.78418963 3.76120012
#  3.98898405]
#
# [0 1]
#
# [11.15606479  9.90348755 10.66895539 10.95080655 11.23848862 11.33857208
#  11.91839057 10.40426284 11.08214255 10.858999   11.36210258  9.79812704
#  11.31447453 11.28978191 10.16585182 10.23995979 10.27505111  9.99879773
#  10.79957558 10.62132735 10.04324949 10.30895266 11.21182037 11.8277362
#   9.680344   10.69194491 11.40756495 10.20359214 11.1844214  10.34174248
#   9.74096862 10.83958091 11.58988651  9.61580548 11.27720313 10.89673933
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0      Gender         Age  EstimatedSalary   Purchased
# count  400.000000  400.000000  400.000000       400.000000  400.000000
# mean   199.500000    0.517500    3.588201        11.021143    0.357500
# std    115.614301    0.500319    0.289846         0.550827    0.479864
# min      0.000000    0.000000    2.890372         9.615805    0.000000
# 25%     99.750000    0.000000    3.401197        10.686198    0.000000
# 50%    199.500000    1.000000    3.610918        11.156158    0.000000
# 75%    299.250000    1.000000    3.828641        11.385092    1.000000
# max    399.000000    1.000000    4.094345        11.918391    1.000000

# %% [markdown]
# ## Deep Dig using Plots

# %% [markdown]
# #### df['Purchased'] = df['Purchased'].map({'No': 0, 'Yes': 1})
# #### df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %%
sns.boxplot(df,x = "Gender", y="Age")
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(df,x = "Gender", y="EstimatedSalary")
# Out:
# <Axes: xlabel='Gender', ylabel='EstimatedSalary'>

# %%
sns.barplot(x=df['Gender'], y=df['Age'])
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.barplot(x=df['Gender'], y=df['EstimatedSalary'])
# Out:
# <Axes: xlabel='Gender', ylabel='EstimatedSalary'>

# %%
sns.barplot(x=df['Purchased'], y=df['Age'])
# Out:
# <Axes: xlabel='Purchased', ylabel='Age'>

# %%
sns.barplot(x=df['Purchased'], y=df['EstimatedSalary'])
# Out:
# <Axes: xlabel='Purchased', ylabel='EstimatedSalary'>

# %%
category_counts = df['Gender'].value_counts()

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart for Gender Categories')
plt.show()

# %%
category_counts = df['Purchased'].value_counts()

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart for Purchased Categories')
plt.show()

# %%
sns.violinplot(df['Age'])
plt.title('Violin Plot for Age')
plt.show()

# %%
sns.violinplot(df['EstimatedSalary'])
plt.title('Violin Plot for EstimatedSalary')
plt.show()

# %% [markdown]
# ## Normality Check

# %% [markdown]
# ### Age Column

# %% [markdown]
# \\ Null Hypothesis : Data is Normal

# %% [markdown]
# \\ Alternate Hypothesis : Data is not Normal

# %%
sns.histplot(df['Age'], kde=1)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df["Age"], kde = True)
plt.axvline(df["Age"].mean(), color="Red")
plt.axvline(df["Age"].median(), color="Green")
plt.axvline(df["Age"].mode()[0], color="Blue")

# Print 
print("Mean : ", df["Age"].mean())
print("Median : ", df["Age"].median())
print("Mode : ", df["Age"].mode()[0])
# Out:
# Mean :  3.588201454814637
# Median :  3.610917912644224
# Mode :  3.555348061489413

# %%
stats.shapiro(df['Age'])
# Out:
# ShapiroResult(statistic=0.975488007068634, pvalue=2.773022515611956e-06)

# %% [markdown]
# ##### Based on the results of the normality test conducted at a significance level of [pvalue=2.773022515611956e-06], we do not have sufficient evidence to accept the null hypothesis. Therefore, we do not conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ### EstimatedSalary Column

# %%
sns.histplot(df['EstimatedSalary'], kde=1)
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Count'>

# %%
sns.histplot(df["EstimatedSalary"], kde = True)
plt.axvline(df["EstimatedSalary"].mean(), color="Red")
plt.axvline(df["EstimatedSalary"].median(), color="Green")
plt.axvline(df["EstimatedSalary"].mode()[0], color="Blue")

# Print 
print("Mean : ", df["EstimatedSalary"].mean())
print("Median : ", df["EstimatedSalary"].median())
print("Mode : ", df["EstimatedSalary"].mode()[0])
# Out:
# Mean :  11.021143066416586
# Median :  11.156157655265122
# Mode :  11.184421397998191

# %%
stats.shapiro(df['EstimatedSalary'])
# Out:
# ShapiroResult(statistic=0.9582976698875427, pvalue=3.1719660231743774e-09)

# %% [markdown]
# ##### Based on the results of the normality test conducted at a significance level of [pvalue=3.1719660231743774e-09], we do not have sufficient evidence to accept the null hypothesis. Therefore, we do not conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ## Levene Test

# %%
group1 = (df['Age'])
group2 = (df["EstimatedSalary"])

# Perform Levene Test
w_stat, p_val = stats.levene(group1, group2)

print("w_statistic:", w_stat)
print("p-value:", p_val)

if p_val < 0.05:  # Assuming alpha level of 0.05
    print(f"Variance are equal : Fail to Reject the null hypothesis")
else:
    print(f"Variance are not equal : Reject the null hypothesis")
# Out:
# w_statistic: 98.73947769124322
# p-value: 5.139400289012397e-22
# Variance are equal : Fail to Reject the null hypothesis

# %% [markdown]
# ##### Based on the results of the homoginity test conducted at a significance level of [p-value:p-value: 5.139400289012397e-22 , w_statistic: 98.73947769124322], (variance are  equal) we do not have sufficient evidence to reject the null hypothesis. Therefore, we do conclude that the data significantly deviates from a normal distribution.

# %% [markdown]
# ## Non Parametric Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       400 non-null    int64
#  1   Gender           400 non-null    int64
#  2   Age              400 non-null    float64
#  3   EstimatedSalary  400 non-null    float64
#  4   Purchased        400 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 15.8 KB

# %% [markdown]
# ### Chi-Squared Test

# %%
contigency_table_1 = pd.crosstab(df["Gender"], df["Purchased"])
contigency_table_1
# Out:
# Purchased    0   1
# Gender
# 0          127  66
# 1          130  77

# %%
chi2, p, dof, expected = stats.chi2_contingency(contigency_table_1)

print()
print("Chi_Square Statistic:", chi2)
print("p-value:", p)
print("Degrees of Freedom:", dof)
print("Expected:", expected)
# Out:
# Chi_Square Statistic: 0.2718905745930978
# p-value: 0.6020663692997424
# Degrees of Freedom: 1
# Expected: [[124.0025  68.9975]
#  [132.9975  74.0025]]

# %% [markdown]
# ### Man-Whittney Test (Independent Sampling)

# %%
from scipy.stats import mannwhitneyu

group1 = df['Age']
group2 = df['EstimatedSalary']

# Perform Mann-Whitney U test
statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

print(f'Mann-Whitney U statistic: {statistic}, p-value: {p_value}')
# Out:
# Mann-Whitney U statistic: 0.0, p-value: 2.30378722815275e-132

# %% [markdown]
# #### Wilcoxon Test (Paired Sampling)

# %%
from scipy.stats import wilcoxon

group1 = df['Age']
group2 = df['EstimatedSalary']

# Perform Mann-Whitney U test
statistic, p_value = wilcoxon(group1, group2, alternative='two-sided')

print(f'Mann-Whitney U statistic: {statistic}, p-value: {p_value}')
# Out:
# Mann-Whitney U statistic: 0.0, p-value: 2.7295025887371262e-67

# %% [markdown]
# ### Correlation

# %%
def pearson(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    x_std = np.std(x)
    y_std = np.std(y)
    n = len(x)
    return sum((x-x_mean)*(y-y_mean))/(n*x_std*y_std)

def spearman(x,y):
    x_rank = pd.Series(x).rank()
    y_rank = pd.Series(y).rank()
    return pearson(x_rank,y_rank)

# Example Dataset
x=(df["Age"])
y=(df["EstimatedSalary"])

print(f"Spearman Correlation Coefficient: {spearman(x,y)}")
# Differentiate all values
if spearman(x,y) < 0.6 > 0:
    print("Positive Relation")
elif spearman(x,y) > 0.6:
    print("Highly Positive Relation")
elif spearman(x,y) > -0.6 < 0:
    print("Negative Correlation")
elif  spearman(x,y) < -0.6:
    print("Highly Negative Correlation")
else:
    print("No Relation")
# Out:
# Spearman Correlation Coefficient: 0.12613264554637543
# Positive Relation

# %%
data =pd.DataFrame({'Age': x, 'EstimatedSalary': y})
heatmap_data = data.corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap between Age and EstimatedSalary')
plt.show()
